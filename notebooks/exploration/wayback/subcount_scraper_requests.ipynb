# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import logging

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# YouTube channel URL
channel_url = "https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ"

# %%
# Function to get all Wayback Machine snapshots
def get_all_snapshots(channel_url):
    api_url = f"http://web.archive.org/cdx/search/cdx?url={channel_url}&output=json&fl=timestamp,original&collapse=digest"
    response = requests.get(api_url)
    snapshots = response.json()
    return snapshots[1:]  # Skip the header

# %%
# Function to scrape subscriber count from snapshot
def scrape_subscriber_count(snapshot_url):
    retries = 5
    for i in range(retries):
        try:
            response = requests.get(snapshot_url)
            response.raise_for_status()  # Raise an exception for HTTP errors
            soup = BeautifulSoup(response.content, "html.parser")
            subscriber_count = None
            
            # Newer version of the page
            sub_count_element_new = soup.find("yt-formatted-string", {"id": "subscriber-count"})
            if sub_count_element_new:
                subscriber_count = sub_count_element_new.text.strip()
            else:
                # Older version of the page
                sub_count_element_old = soup.find("span", {
                    "class": "yt-subscription-button-subscriber-count-branded-horizontal subscribed yt-uix-tooltip"})
                if sub_count_element_old:
                    subscriber_count = sub_count_element_old.text.strip()

            return subscriber_count
        except requests.exceptions.RequestException as e:
            logging.error(f"Error scraping {snapshot_url}: {e}")
            time.sleep(10 ** i + random.uniform(5, 10))  # Exponential backoff
    return None

# %%
# Collecting data
data = []
i = 1
snapshots = get_all_snapshots(channel_url)
logging.info(f"Found {len(snapshots)} snapshots for the channel URL")

for snapshot in snapshots:
    timestamp = snapshot[0]
    original_url = snapshot[1]
    snapshot_url = f"https://web.archive.org/web/{timestamp}/{original_url}"
    subscriber_count = scrape_subscriber_count(snapshot_url)
    data.append({
        "snapshot_url": snapshot_url,
        "timestamp": timestamp,
        "subscriber_count": subscriber_count
    })
    print(subscriber_count)
    logging.info(f"{i}: Scraped subscriber count for snapshot: {snapshot_url}")
    i += 1
    time.sleep(random.uniform(15, 60))  # Delay between requests to respect rate limits
# Out:
# 2024-08-02 23:44:07,276 - INFO - Found 508 snapshots for the channel URL
# 2024-08-02 23:44:08,390 - INFO - 1: Scraped subscriber count for snapshot: https://web.archive.org/web/20190416052508/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 12,097
# 2024-08-02 23:44:28,241 - INFO - 2: Scraped subscriber count for snapshot: https://web.archive.org/web/20190416054303/http://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 12,097
# 2024-08-02 23:45:16,280 - INFO - 3: Scraped subscriber count for snapshot: https://web.archive.org/web/20190508021050/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 18,975
# 2024-08-02 23:46:01,153 - INFO - 4: Scraped subscriber count for snapshot: https://web.archive.org/web/20190619220015/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 27.326
# 2024-08-02 23:46:25,734 - INFO - 5: Scraped subscriber count for snapshot: https://web.archive.org/web/20190703190003/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 29 218
# 2024-08-02 23:47:20,670 - INFO - 6: Scraped subscriber count for snapshot: https://web.archive.org/web/20190729095430/http://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 31,875
# 2024-08-02 23:47:52,547 - INFO - 7: Scraped subscriber count for snapshot: https://web.archive.org/web/20190729095434/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 31,875
# 2024-08-02 23:48:27,767 - INFO - 8: Scraped subscriber count for snapshot: https://web.archive.org/web/20190916180218/http://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 35.8K
# 2024-08-02 23:48:56,759 - INFO - 9: Scraped subscriber count for snapshot: https://web.archive.org/web/20190916180231/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 35.8K
# 2024-08-02 23:49:36,336 - INFO - 10: Scraped subscriber count for snapshot: https://web.archive.org/web/20191203073220/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-02 23:50:21,917 - INFO - 11: Scraped subscriber count for snapshot: https://web.archive.org/web/20191204005701/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-02 23:50:43,117 - INFO - 12: Scraped subscriber count for snapshot: https://web.archive.org/web/20191204023248/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-02 23:51:03,411 - INFO - 13: Scraped subscriber count for snapshot: https://web.archive.org/web/20191231161159/http://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 49.3K
# 2024-08-02 23:51:50,147 - INFO - 14: Scraped subscriber count for snapshot: https://web.archive.org/web/20191231161221/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 49.3K
# 2024-08-02 23:52:34,424 - INFO - 15: Scraped subscriber count for snapshot: https://web.archive.org/web/20200103183322/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-02 23:53:02,423 - INFO - 16: Scraped subscriber count for snapshot: https://web.archive.org/web/20200112144839/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 51,1 тыс.
# 2024-08-02 23:53:33,813 - INFO - 17: Scraped subscriber count for snapshot: https://web.archive.org/web/20200313205304/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-02 23:54:24,257 - INFO - 18: Scraped subscriber count for snapshot: https://web.archive.org/web/20200429002423/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-02 23:54:55,893 - INFO - 19: Scraped subscriber count for snapshot: https://web.archive.org/web/20200429215336/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-02 23:55:32,703 - INFO - 20: Scraped subscriber count for snapshot: https://web.archive.org/web/20200502181123/http://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 78.2K
# 2024-08-02 23:56:23,996 - INFO - 21: Scraped subscriber count for snapshot: https://web.archive.org/web/20200502181142/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 78.2K
# 2024-08-02 23:57:22,993 - INFO - 22: Scraped subscriber count for snapshot: https://web.archive.org/web/20200502181211/http://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 78.2K
# 2024-08-02 23:58:09,467 - INFO - 23: Scraped subscriber count for snapshot: https://web.archive.org/web/20200502181314/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 78.2K
# 2024-08-02 23:58:37,306 - INFO - 24: Scraped subscriber count for snapshot: https://web.archive.org/web/20200510145232/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-02 23:59:29,943 - INFO - 25: Scraped subscriber count for snapshot: https://web.archive.org/web/20200531025920/http://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:00:19,373 - INFO - 26: Scraped subscriber count for snapshot: https://web.archive.org/web/20200601122515/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:00:36,449 - INFO - 27: Scraped subscriber count for snapshot: https://web.archive.org/web/20200603022444/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:01:03,575 - INFO - 28: Scraped subscriber count for snapshot: https://web.archive.org/web/20200603022522/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:01:28,802 - INFO - 29: Scraped subscriber count for snapshot: https://web.archive.org/web/20200609030244/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:02:14,581 - INFO - 30: Scraped subscriber count for snapshot: https://web.archive.org/web/20200613020620/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:02:56,154 - INFO - 31: Scraped subscriber count for snapshot: https://web.archive.org/web/20200615123901/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# 116K
# 2024-08-03 00:03:18,908 - INFO - 32: Scraped subscriber count for snapshot: https://web.archive.org/web/20200615153512/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:03:38,668 - INFO - 33: Scraped subscriber count for snapshot: https://web.archive.org/web/20200701025711/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:04:37,940 - INFO - 34: Scraped subscriber count for snapshot: https://web.archive.org/web/20200702210454/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:05:25,195 - INFO - 35: Scraped subscriber count for snapshot: https://web.archive.org/web/20200706093422/http://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:05:43,972 - INFO - 36: Scraped subscriber count for snapshot: https://web.archive.org/web/20200706093435/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:06:49,960 - INFO - 37: Scraped subscriber count for snapshot: https://web.archive.org/web/20200707224819/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:18:12,586 - INFO - 38: Scraped subscriber count for snapshot: https://web.archive.org/web/20200707225803/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# 2024-08-03 00:19:35,739 - INFO - 39: Scraped subscriber count for snapshot: https://web.archive.org/web/20200707225952/https://www.youtube.com/channel/UC1E-JS8L0j1Ei70D9VEFrPQ
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 11
#       9 original_url = snapshot[1]
#      10 snapshot_url = f"https://web.archive.org/web/{timestamp}/{original_url}"
# ---> 11 subscriber_count = scrape_subscriber_count(snapshot_url)
#      12 data.append({
#      13     "snapshot_url": snapshot_url,
#      14     "timestamp": timestamp,
#      15     "subscriber_count": subscriber_count
#      16 })
#      17 print(subscriber_count)
#
# Cell In[13], line 6, in scrape_subscriber_count(snapshot_url)
#       4 for i in range(retries):
#       5     try:
# ----> 6         response = requests.get(snapshot_url)
#       7         response.raise_for_status()  # Raise an exception for HTTP errors
#       8         soup = BeautifulSoup(response.content, "html.parser")
#
# File ~/Documents/YouTube/DiscoData/Youtube API/Youtube API/.venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/YouTube/DiscoData/Youtube API/Youtube API/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/YouTube/DiscoData/Youtube API/Youtube API/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/YouTube/DiscoData/Youtube API/Youtube API/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/YouTube/DiscoData/Youtube API/Youtube API/.venv/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Documents/YouTube/DiscoData/Youtube API/Youtube API/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Documents/YouTube/DiscoData/Youtube API/Youtube API/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/YouTube/DiscoData/Youtube API/Youtube API/.venv/lib/python3.11/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Convert data to DataFrame for easier analysis
df = pd.DataFrame(data)
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y%m%d%H%M%S')
print(df)

# Save to CSV
df.to_csv("channel_subscriber_counts_all_snapshots.csv", index=False)
